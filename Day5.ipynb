# %%
"Hello"
# Out:
# 'Hello'

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]

# %%
plt.plot(x,y,'ro--',linewidth=2.0)
plt.title("Plotting random numbers")
plt.xlabel("Numbers")
plt.ylabel("Numbers * 10")
plt.grid(True)
plt.show()

# %%
subject=["M1","M2","CHEM","PHY"]
marks=["15","19","18","11"]

# %%
plt.bar(subject,marks,color="Black")
plt.title("Marks in each subject")
plt.xlabel("subjects")
plt.ylabel("Marks obtained")
plt.grid(True)
plt.show()

# %%
plt.plot(subject,marks,color="Black")
plt.title("Marks in each subject")
plt.xlabel("subjects")
plt.ylabel("Marks obtained")
plt.grid(True)
plt.show()

# %%
plt.scatter(subject,marks,color="Black")
plt.title("Marks in each subject")
plt.xlabel("subjects")
plt.ylabel("Marks obtained")
plt.grid(True)
plt.show()

# %%
subject=["M1","M2","CHEM","PHY"]
marks=[15,19,18,11]

# %%
plt.scatter(subject,marks,color="Black")
plt.title("Marks in each subject")
plt.xlabel("subjects")
plt.ylabel("Marks obtained")
plt.grid(True)
plt.show()

# %%
total=[20,20,20,20]
plt.pie(marks,labels= ["m1","m2","physics","chemistry"])
plt.title("Marks in each subject")
plt.show()

# %%
plt.bar(subject,marks,color="green")
plt.title("Marks in each subject")
plt.xlabel("subjects")
plt.ylabel("Marks obtained")
plt.grid(True)
plt.show()

# %%
plt.barh(subject,marks,color="orange")
plt.title("Marks in each subject")
plt.xlabel("subjects")
plt.ylabel("Marks obtained")
plt.grid(True)
plt.show()

# %%
import pyttsx3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 import pyttsx3
#
# ModuleNotFoundError: No module named 'pyttsx3'

# %%
pip install pyttsx3
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
# ...

# %%
import pyttsx3

# %%
speaker=pyttsx3.init()
speaker.say("Good afternoon Dheeraj Sir ")
speaker.runAndWait()

# %%
speaker.say("Good afternoon sir ")
speaker.runAndWait()

# %%
speaker.say("h")

# %%
import SpeechRecognition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 import SpeechRecognition
#
# ModuleNotFoundError: No module named 'SpeechRecognition'

# %%
pip install SpeechRecognition
# Out:
# ...
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    - -------------------------------------- 1.3/32.9 MB 4.3 MB/s eta 0:00:08
#    -- ------------------------------------- 2.1/32.9 MB 4.2 MB/s eta 0:00:08
#    --- ------------------------------------ 2.9/32.9 MB 4.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 3.7/32.9 MB 4.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 4.2/32.9 MB 3.7 MB/s eta 0:00:08
#    ----- ---------------------------------- 4.7/32.9 MB 3.6 MB/s eta 0:00:08
#    ------- -------------------------------- 5.8/32.9 MB 3.7 MB/s eta 0:00:08
#    ------- -------------------------------- 6.6/32.9 MB 3.9 MB/s eta 0:00:07
#    --------- ------------------------------ 7.9/32.9 MB 4.0 MB/s eta 0:00:07
#    ---------- ----------------------------- 8.7/32.9 MB 4.0 MB/s eta 0:00:06
# ...

# %%
pip install PyAudio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr

# %%
mic=sr.Recognizer()

# %%
with sr.Microphone() as source:
    print("Start speaking ...")
    voice= mic.listen(source)
    text =mic.recognize_google(voice)
    print("You said this",text)
# Out:
# Start speaking ...
# You said this hello hello hello hay

# %%
import pywhatkit

# %%
with sr.Microphone() as s:
    print("Say Anything ..")
    voice = mic.listen(s)
    text=mic.recognize_google(voice)
    print(text)
# Out:
# Say Anything ..
# hello

# %%
pywhatkit.sendwhatmsg_instantly("+918802541412","Hello")

# %%
pywhatkit.sendwhatmsg("+918802541412","Dhan nirankar ji",time_hour=14,time_min=50)
# Out:
# In 9 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!

# %%
pywhatkit.sendwhatmsg_instantly("+918851432650","Dhan nirankar ji")

# %%
pywhatkit.sendwhatmsg_to_group("IFTgT5cqLZoHVROqfRFT1D","Hello",14,56)
# Out:
# In 18 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!

# %%
import webbrowser

# %%
webbrowser.open_new_tab("https://github.com/")
# Out:
# True

# %%
import os

# %%
os.startfile("D:\Internship training\myfile.txt")

# %%
os.open(
