# %%
def print_name(n):
    print(f'Hi {n}')

# %%
print_name("Vinamra")
# Out:
# Hi Vinamra

# %%
def multi_args(*args):
    print(args)

# %%
multi_args("hhbdhd","sdbhd")
# Out:
# ('hhbdhd', 'sdbhd')

# %%
def student(**info):
    for key , value in info.items():
        print(key, ":", value)

# %%
tom_details=student(name="Tom",contact=123)
# Out:
# name : Tom
# contact : 123

# %%
def myfunc(a,b):
    return a+b, a-b

# %%
myfunc(3,5)
# Out:
# (8, -2)

# %%
double= lambda x: x*2

# %%
double(5)
# Out:
# 10

# %%
triple=lambda x:x*3

# %%
triple(10)
# Out:
# 30

# %%
import function

# %%
function.greet("Vinamra")
# Out:
# Hello Vinamra

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt

# %%
from function import

# %%
import random as r

# %%
r.randint(1,20)
# Out:
# 19

# %%
import datetime as d

# %%
print(d.datetime.time(tzinfo="Asia/Jaipur"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(d.datetime.time(tzinfo="Asia/Jaipur"))
#
# TypeError: unbound method datetime.time() needs an argument

# %%
try:
    exec('print("Hello"n)')
except SyntaxError:
    print("Use the correct syntax")
# Out:
# Use the correct syntax
