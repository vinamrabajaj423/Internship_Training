# %%
pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\gargv\anaconda3\lib\site-packages (3.1.0)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\gargv\anaconda3\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\gargv\anaconda3\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\gargv\anaconda3\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\gargv\anaconda3\lib\site-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in c:\users\gargv\anaconda3\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: colorama in c:\users\gargv\anaconda3\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gargv\anaconda3\lib\site-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask

# %%
app = Flask(__name__)

@app.route("/")
def home() :
    return """ 
    <h1> I am home page</h1>
     <h2> I am running in flask </h2>
     """
    
@app.route("/about")
def abouta() :
    return """ 
    <h1> I am home page</h1>
     <h2> I am running in flask </h2>
     """
if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [23/Nov/2025 12:23:32] "GET / HTTP/1.1" 200 -

# %%
app = Flask(__name__)

@app.route("/")
def home() :
    return """ 
    <h1> I am vaishali </h1>
    <h2> a Btech second year student </h2>
     """
if __name__=='__main__':
    app.run()

# %%
app = Flask(__name__)

@app.route("/")
def home() :
    return """ 
    <h1> I am vaishali </h1>
    <p>  a Btech second year student <p>
    """
if __name__=='__main__':
    app.run()

# %%
app = Flask(__name__)

@app.route("/")
def home() :
    return """ 
    <h1> I am home page</h1>
     <h2> I am running in flask </h2>
     """
if __name__=='__main__':
    app.run()
